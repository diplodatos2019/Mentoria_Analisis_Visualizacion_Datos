# %% [markdown]
# # Practico Mentoria - Analisis y Visualizacion de Datos

# %% [markdown]
# ---

# %% [markdown]
# ### Importaciones

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

from collections import OrderedDict
from IPython.display import display

import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style("whitegrid")
sns.set_context('talk')

# %%
# Seteamos una semilla para Reproducibilidad
np.random.seed(1)

# %% [markdown]
# ---

# %% [markdown]
# ### Carga de los Datesets

# %%
df_player = pd.read_csv('./Datasets/football_player.csv')
df_team = pd.read_csv('./Datasets/football_team.csv')
df_match = pd.read_csv('./Datasets/football_match.csv')

# %% [markdown]
# ### Exploremos un poco los Datasets

# %% [markdown]
# > #### Players Dataset

# %%
print("Shape = {}".format(df_player.shape))
# Out:
# Shape = (9925, 42)

# %%
df_player.sample(10)
# Out:
#                  player_name    birthday  height  weight  overall_rating  \
# 858           Ariel Borysiuk  1991-07-29  180.34     154           66.12
# 8529  Sava Miladinovic Bento  1991-01-02  182.88     159           58.00
# 2527             Dusan Tadic  1988-11-20  180.34     168           78.16
# 8473        Samuel Souprayen  1989-02-18  187.96     165           64.24
# 1958           Daniele Croce  1982-09-09  172.72     150           67.68
# 4555         John Arne Riise  1980-09-24  187.96     181           76.32
# 8408             Saidy Janko  1995-10-22  177.80     154           62.13
# 3743          Helder Postiga  1982-08-02  180.34     168           76.04
# 2314           Denzel Slager  1993-05-02  182.88     179           61.50
# 2992         Fernando Marcal  1989-02-19  177.80     159           70.88
#
#       potential preferred_foot attacking_work_rate defensive_work_rate  \
# 858       74.38          right              medium                high
# 8529      64.43          right              medium              medium
# 2527      81.88           left              medium              medium
# 8473      71.76           left              medium              medium
# 1958      67.68          right                high              medium
# 4555      77.64           left                high              medium
# 8408      76.53          right                high              medium
# 3743      76.93          right                high                high
# 2314      70.75           left                high              medium
# 2992      75.41           left                high              medium
#
#       crossing  ...  vision  penalties  marking  standing_tackle  \
# 858      56.92  ...   70.46      49.21    51.58            63.58
# 8529     51.07  ...   59.64      49.50    41.64            46.57
# 2527     81.52  ...   84.32      76.28    39.96            35.56
# 8473     58.29  ...   46.52      42.71    65.62            65.19
# 1958     63.32  ...   68.47      59.74    52.26            56.89
# 4555     84.00  ...   64.14      70.59    75.45            79.59
# 8408     58.73  ...   41.00      51.20    58.53            65.87
# 3743     59.33  ...   67.15      70.59    25.37            28.11
# 2314     60.25  ...   47.00      50.00    20.62            20.00
# 2992     72.53  ...   51.53      42.35    65.47            70.00
#
#       sliding_tackle  gk_diving  gk_handling  gk_kicking  gk_positioning  \
# 858            63.08      12.71        13.04       18.71           15.54
# 8529           40.07       8.00         8.00        8.00            7.00
# 2527           27.56      10.16        10.16       12.56            8.16
# 8473           66.90       8.33        10.95       15.19           14.19
# 1958           59.53      11.74        11.74        5.74            7.74
# 4555           80.59      13.27        10.09       33.14           13.50
# 8408           64.60       5.27         9.27        7.27           13.27
# 3743           27.19      12.00         9.81       20.67           16.37
# 2314           21.00      14.00         8.00       11.00           11.00
# 2992           71.53       5.35        10.35       13.35           12.35
#
#       gk_reflexes
# 858         13.04
# 8529        14.00
# 2527        15.16
# 8473        14.19
# 1958        12.74
# 4555        13.68
# 8408         7.27
# 3743        14.59
# 2314        15.00
# 2992        10.35
#
# [10 rows x 42 columns]

# %%
df_player.dtypes
# Out:
# player_name             object
# birthday                object
# height                 float64
# weight                   int64
# overall_rating         float64
# potential              float64
# preferred_foot          object
# attacking_work_rate     object
# defensive_work_rate     object
# crossing               float64
# finishing              float64
# heading_accuracy       float64
# short_passing          float64
# volleys                float64
# dribbling              float64
# curve                  float64
# free_kick_accuracy     float64
# long_passing           float64
# ball_control           float64
# acceleration           float64
# sprint_speed           float64
# agility                float64
# reactions              float64
# balance                float64
# shot_power             float64
# jumping                float64
# stamina                float64
# strength               float64
# long_shots             float64
# aggression             float64
# interceptions          float64
# positioning            float64
# vision                 float64
# penalties              float64
# marking                float64
# standing_tackle        float64
# sliding_tackle         float64
# gk_diving              float64
# gk_handling            float64
# gk_kicking             float64
# gk_positioning         float64
# gk_reflexes            float64
# dtype: object

# %% [markdown]
# > #### Teams Dataset

# %%
print("Shape = {}".format(df_team.shape))
# Out:
# Shape = (288, 22)

# %%
df_team.sample(10)
# Out:
#              team_long_name team_short_name  buildUpPlaySpeed  \
# 276          BSC Young Boys              YB             53.83
# 98            VfL Wolfsburg             WOL             61.33
# 186             Widzew Łódź             LOD             65.25
# 73   FC Sochaux-Montbéliard             SOC             61.33
# 269        RC Celta de Vigo             CEL             48.67
# 226     Heart of Midlothian             HEA             59.60
# 35            Middlesbrough             MID             62.67
# 154                 Vitesse             VIT             42.00
# 253     Real Betis Balompié             BET             52.33
# 108           Karlsruher SC             KAR             57.40
#
#     buildUpPlaySpeedClass buildUpPlayDribblingClass  buildUpPlayPassing  \
# 276              Balanced                    Little               63.00
# 98               Balanced                    Little               51.33
# 186              Balanced                    Little               62.75
# 73               Balanced                    Little               46.00
# 269              Balanced                    Little               49.67
# 226              Balanced                    Little               60.00
# 35               Balanced                    Little               55.83
# 154              Balanced                    Little               39.00
# 253              Balanced                    Little               40.67
# 108              Balanced                    Little               47.40
#
#     buildUpPlayPassingClass buildUpPlayPositioningClass  \
# 276                   Mixed                   Organised
# 98                    Mixed                   Organised
# 186                    Long                   Organised
# 73                    Mixed                   Organised
# 269                   Mixed                   Organised
# 226                   Mixed                   Organised
# 35                    Mixed                   Organised
# 154                   Mixed                   Organised
# 253                   Mixed                   Organised
# 108                   Mixed                   Organised
#
#      chanceCreationPassing chanceCreationPassingClass  ...  \
# 276                  46.00                     Normal  ...
# 98                   67.00                      Risky  ...
# 186                  56.75                     Normal  ...
# 73                   53.67                     Normal  ...
# 269                  52.67                     Normal  ...
# 226                  58.40                     Normal  ...
# 35                   51.00                     Normal  ...
# 154                  53.83                     Normal  ...
# 253                  55.67                     Normal  ...
# 108                  60.00                     Normal  ...
#
#      chanceCreationShooting chanceCreationShootingClass  \
# 276                   52.00                      Normal
# 98                    57.17                      Normal
# 186                   53.00                      Normal
# 73                    46.83                      Normal
# 269                   56.00                      Normal
# 226                   64.00                      Normal
# 35                    56.00                      Normal
# 154                   59.83                      Normal
# 253                   56.50                      Normal
# 108                   54.60                      Normal
#
#      chanceCreationPositioningClass defencePressure defencePressureClass  \
# 276                       Organised           46.50               Medium
# 98                        Organised           55.00               Medium
# 186                       Organised           34.25                 Deep
# 73                        Organised           54.33               Medium
# 269                       Organised           42.67               Medium
# 226                       Organised           53.40               Medium
# 35                        Organised           39.33               Medium
# 154                       Organised           45.17               Medium
# 253                       Organised           54.00               Medium
# 108                       Organised           43.40               Medium
#
#      defenceAggression defenceAggressionClass  defenceTeamWidth  \
# 276              40.00                  Press             53.50
# 98               47.17                  Press             53.00
# 186              42.75                  Press             59.00
# 73               42.83                  Press             54.33
# 269              47.00                  Press             59.50
# 226              59.00                  Press             61.40
# 35               47.00                  Press             42.83
# 154              50.17                  Press             52.33
# 253              46.83                  Press             56.67
# 108              44.80                  Press             45.40
#
#     defenceTeamWidthClass  defenceDefenderLineClass
# 276                Normal                     Cover
# 98                 Normal                     Cover
# 186                Normal                     Cover
# 73                 Normal                     Cover
# 269                Normal                     Cover
# 226                Normal                     Cover
# 35                 Normal                     Cover
# 154                Normal                     Cover
# 253                Normal                     Cover
# 108                Normal                     Cover
#
# [10 rows x 22 columns]

# %%
df_team.dtypes
# Out:
# team_long_name                     object
# team_short_name                    object
# buildUpPlaySpeed                  float64
# buildUpPlaySpeedClass              object
# buildUpPlayDribblingClass          object
# buildUpPlayPassing                float64
# buildUpPlayPassingClass            object
# buildUpPlayPositioningClass        object
# chanceCreationPassing             float64
# chanceCreationPassingClass         object
# chanceCreationCrossing            float64
# chanceCreationCrossingClass        object
# chanceCreationShooting            float64
# chanceCreationShootingClass        object
# chanceCreationPositioningClass     object
# defencePressure                   float64
# defencePressureClass               object
# defenceAggression                 float64
# defenceAggressionClass             object
# defenceTeamWidth                  float64
# defenceTeamWidthClass              object
# defenceDefenderLineClass           object
# dtype: object

# %% [markdown]
# > #### Matchs Dataset

# %%
print("Shape = {}".format(df_match.shape))
# Out:
# Shape = (25979, 14)

# %%
df_match.sample(10)
# Out:
#       country_name             league_name     season  stage        date  \
# 15289  Netherlands  Netherlands Eredivisie  2014/2015     28  2015-03-20
# 6697        France          France Ligue 1  2013/2014     11  2013-10-26
# 15489  Netherlands  Netherlands Eredivisie  2015/2016     17  2015-12-19
# 2579       England  England Premier League  2010/2011     18  2011-01-26
# 10264        Italy           Italy Serie A  2008/2009      1  2008-08-31
# 17444       Poland      Poland Ekstraklasa  2015/2016     14  2015-10-30
# 11088        Italy           Italy Serie A  2010/2011     16  2010-12-12
# 467        Belgium  Belgium Jupiler League  2009/2010     30  2010-03-21
# 17525       Poland      Poland Ekstraklasa  2015/2016     23  2016-02-21
# 15773       Poland      Poland Ekstraklasa  2008/2009     15  2008-11-22
#
#       home_team_long_name home_short_long_name       away_team_long_name  \
# 15289          FC Utrecht                  UTR                 NAC Breda
# 6697      Valenciennes FC                  VAL  Évian Thonon Gaillard FC
# 15489     Heracles Almelo                  HER              FC Groningen
# 2579            Liverpool                  LIV                    Fulham
# 10264              Torino                  TOR                     Lecce
# 17444       Górnik Łęczna                  LEC                  Cracovia
# 11088             Brescia                  BRE                 Sampdoria
# 467     Standard de Liège                  STL                  KAA Gent
# 17525       Polonia Bytom                  GOR              Ruch Chorzów
# 15773       GKS Bełchatów                  BEL     Jagiellonia Białystok
#
#       away_short_long_name  home_team_goal  away_team_goal  B365H  B365D  \
# 15289                  NAC               3               4   1.50    3.9
# 6697                   ETG               0               1   2.00    3.3
# 15489                  GRO               2               1   2.20    3.4
# 2579                   FUL               1               0   1.53    3.8
# 10264                  LEC               3               0   1.80    3.1
# 17444                  CKR               1               0    NaN    NaN
# 11088                  SAM               1               0   2.90    3.1
# 467                    GEN               0               2   1.85    3.6
# 17525                  CHO               0               2    NaN    NaN
# 15773                  BIA               2               0    NaN    NaN
#
#        B365A
# 15289   7.00
# 6697    3.80
# 15489   3.20
# 2579    7.00
# 10264   5.25
# 17444    NaN
# 11088   2.55
# 467     4.00
# 17525    NaN
# 15773    NaN

# %%
df_match.dtypes
# Out:
# country_name             object
# league_name              object
# season                   object
# stage                     int64
# date                     object
# home_team_long_name      object
# home_short_long_name     object
# away_team_long_name      object
# away_short_long_name     object
# home_team_goal            int64
# away_team_goal            int64
# B365H                   float64
# B365D                   float64
# B365A                   float64
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ### Ejercicios

# %% [markdown]
# > Ejercicio 1
#
# Calcular Estadisticos como son:
# * Moda
# * Media
# * Mediana
# * Desviacion Estandar
# * Minimo y Maximo
#
# de variables como la Altura y el Peso de los jugadores.
#
# Ver si responden a alguna distribución conocida.

# %% [markdown]
# > Ejercicio 2
#
# Realizar un Análisis de valores atípicos (outliers)

# %% [markdown]
# > Ejercicio 3
#
# Explicar cómo varían las métricas cuando se desglosan por la pierna hábil de cada jugador (diestro o zurdo), Comparar cualitativamente y gráficamente ambas distribuciones.

# %% [markdown]
# > Ejercicio 4
#
# Calcular la correlación entre las variables de los jugadores.

# %% [markdown]
# > Ejercicio 5: Preguntas
#
# * Cual es la Liga Europea con mayor cantidad de partidos? Graficar.
# * Cual es la temporada en donde hubo mayor cantidad de partidos? Graficar.
# * Los 10 equipos con mayor cantidad de goles de local. Graficar.
# * Los 10 equipos con mayor cantidad de goles de visitante. Graficar.
# * El equipo que convierte la mayor cantidad de goles. Graficar.
#
# **Extra:** Si se les ocurre algún otra métrica que puedan extraer de los datasets, los invito a que la hagan.

# %% [markdown]
# ---
